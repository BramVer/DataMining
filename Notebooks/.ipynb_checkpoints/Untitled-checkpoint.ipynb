# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.io.shapereader as shpreader
import itertools
import numpy as np

shapename = '../Data/admin_0_countries'
countries_shp = shpreader.natural_earth(resolution='110m',
                                        category='cultural', name=shapename)

# some nice "earthy" colors
earth_colors = np.array([(199, 233, 192),
                                (161, 217, 155),
                                (116, 196, 118),
                                (65, 171, 93),
                                (35, 139, 69),
                                ]) / 255.
earth_colors = itertools.cycle(earth_colors)



ax = plt.axes(projection=ccrs.PlateCarree())
for country in shpreader.Reader(countries_shp).records():
    print country.attributes['name_long'], earth_colors.next()
    ax.add_geometries(country.geometry, ccrs.PlateCarree(),
                      facecolor=earth_colors.next(),
                      label=country.attributes['name_long'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\backends\backend_qt5.pyc in resizeEvent(self, event)
#     336         self.figure.set_size_inches(winch, hinch)
#     337         FigureCanvasBase.resize_event(self)
# --> 338         self.draw()
#     339         self.update()
#     340         QtWidgets.QWidget.resizeEvent(self, event)
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\backends\backend_qt5agg.pyc in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\backends\backend_agg.pyc in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\figure.pyc in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Program Files\Anaconda2\lib\site-packages\cartopy\mpl\geoaxes.pyc in draw(self, renderer, inframe)
#     358
#     359         return matplotlib.axes.Axes.draw(self, renderer=renderer,
# --> 360                                          inframe=inframe)
#     361
#     362     def __str__(self):
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Program Files\Anaconda2\lib\site-packages\cartopy\mpl\feature_artist.pyc in draw(self, renderer, *args, **kwargs)
#     173         c = matplotlib.collections.PathCollection(paths,
#     174                                                   transform=transform,
# --> 175                                                   **final_kwargs)
#     176         c.set_clip_path(ax.patch)
#     177         c.set_figure(ax.figure)
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\collections.pyc in __init__(self, paths, sizes, **kwargs)
#     786         """
#     787
# --> 788         Collection.__init__(self, **kwargs)
#     789         self.set_paths(paths)
#     790         self.set_sizes(sizes)
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\collections.pyc in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     133
#     134         self._path_effects = None
# --> 135         self.update(kwargs)
#     136         self._paths = None
#     137
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in update(self, props)
#     756             if func is None or not six.callable(func):
#     757                 raise AttributeError('Unknown property %s' % k)
# --> 758             func(v)
#     759             changed = True
#     760         self.eventson = store
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in set_label(self, s)
#     775         """
#     776         if s is not None:
# --> 777             self._label = '%s' % (s, )
#     778         else:
#     779             self._label = None
#
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xf4 in position 1: invalid continuation byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\backends\backend_qt5.pyc in resizeEvent(self, event)
#     336         self.figure.set_size_inches(winch, hinch)
#     337         FigureCanvasBase.resize_event(self)
# --> 338         self.draw()
#     339         self.update()
#     340         QtWidgets.QWidget.resizeEvent(self, event)
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\backends\backend_qt5agg.pyc in draw(self)
#     146         # causes problems with code that uses the result of the
#     147         # draw() to update plot elements.
# --> 148         FigureCanvasAgg.draw(self)
#     149         self._priv_update()
#     150
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\backends\backend_agg.pyc in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\figure.pyc in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Program Files\Anaconda2\lib\site-packages\cartopy\mpl\geoaxes.pyc in draw(self, renderer, inframe)
#     358
#     359         return matplotlib.axes.Axes.draw(self, renderer=renderer,
# --> 360                                          inframe=inframe)
#     361
#     362     def __str__(self):
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# C:\Program Files\Anaconda2\lib\site-packages\cartopy\mpl\feature_artist.pyc in draw(self, renderer, *args, **kwargs)
#     173         c = matplotlib.collections.PathCollection(paths,
#     174                                                   transform=transform,
# --> 175                                                   **final_kwargs)
#     176         c.set_clip_path(ax.patch)
#     177         c.set_figure(ax.figure)
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\collections.pyc in __init__(self, paths, sizes, **kwargs)
#     786         """
#     787
# --> 788         Collection.__init__(self, **kwargs)
#     789         self.set_paths(paths)
#     790         self.set_sizes(sizes)
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\collections.pyc in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     133
#     134         self._path_effects = None
# --> 135         self.update(kwargs)
#     136         self._paths = None
#     137
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in update(self, props)
#     756             if func is None or not six.callable(func):
#     757                 raise AttributeError('Unknown property %s' % k)
# --> 758             func(v)
#     759             changed = True
#     760         self.eventson = store
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\artist.pyc in set_label(self, s)
#     775         """
#     776         if s is not None:
# --> 777             self._label = '%s' % (s, )
#     778         else:
#     779             self._label = None
#
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xf4 in position 1: invalid continuation byte
